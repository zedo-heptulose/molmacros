# %%
import molecule as mol

# %%
"""
I will have to see about what to do.

So, to make the unit cell, I have some idea of a bond at the boundary, right?

like, there's *structurally* a breaking point,
that I can use to obtain translation vectors.


then I would want to make sure that the whole molecule is inside the unit cell,
with the translation vectors starting at the origin, right?

...
"""
# Out:
# "\nI will have to see about what to do.\n\nSo, to make the unit cell, I have some idea of a bond at the boundary, right?\n\nlike, there's *structurally* a breaking point,\nthat I can use to obtain translation vectors.\n\n\nthen I would want to make sure that the whole molecule is inside the unit cell,\nwith the translation vectors starting at the origin, right?\n\n...\n"
