# %%
cd MolMakerClean
# Out:
# /gpfs/home/gdb20/code/mol_maker/MolMakerClean

# %%
import numpy as np
import os
import molecule as mol
import utilities as util
import mol_tree as mt

# %%
cd ../data/mike_og5
# Out:
# /gpfs/home/gdb20/code/mol_maker/data/mike_og5

# %%
molecules = {}
for filename in os.listdir('.'):
    basename = os.path.splitext(filename)[0]
    molecules[basename] = mol.Molecule(filename=filename)

# %%
molecules
# Out:
# {'cby': <molecule.Molecule at 0x1468d2ee1290>,
#  'cmy': <molecule.Molecule at 0x1468d3603a90>,
#  'ome': <molecule.Molecule at 0x1468d35eda10>,
#  'oby': <molecule.Molecule at 0x1468d2ee3790>,
#  'omy': <molecule.Molecule at 0x1468d2ee36d0>}

# %%
molecules['omy'].show()
