# %%
import molecule as mol
import utilities as util
import os 
import re

# %%
mols = {}
for file in os.listdir('../data/stgaps_coordinates'):
    mols[os.path.basename(file).split('.')[0]] = mol.Molecule(filename=f'../data/stgaps_coordinates/{file}')

list_names = [string for string in mols]

# %%
mkdir xy_coords

# %%
new_9 = mols[list_names[9]]
new_9.show()

# %%
new_9 = new_9.align_to_plane(['C37','C21','C24'])
print(list_names[9])
new_9.show()
# Out:
# ome_singlet_uks_cam_b3lyp_631gdp_brsym

# %%
new_9.write_xyz(filename=f'./xy_coords/xy_{list_names[9]}.xyz')

# %%
len(list_names)
# Out:
# 10
